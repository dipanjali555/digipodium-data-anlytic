# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
marks = pd.read_excel('marksheet_faked.xlsx')
marks
# Out:
#     S.no   First name   Last name  DM  SE  GFX  DBMS  ECO
# 0      1     Sandhya        Singh  60  87   34    55   79
# 1      2       Pinki        Yadav  49  73   53    51   96
# 2      3      Ankita        Verma  77  77   96    93   79
# 3      4   Dipanjali        Singh  67  36   37    89   39
# 4      5      Khushi      Awasthi  34  90   59    33   47
# 5      6     Shalini          Pal  33  64   97    59   67
# 6      7      Saloni         Gond  60  64  100    97   37
# 7      8     Anushka   Srivastava  62  44   94    89   52
# 8      9       Aditi       Pandey  30  91   63   100   84
# 9     10       Umama        Anjum  84  38   37    92   86
# 10    11      Muskan        Singh  44  58   74    81   57
# 11    12       Kajal       Pandey  83  54   40    75   30
# 12    13     Anshika        Yadav  35  55   57    73   79
# 13    14     Deepika         Soni  69  87   99    82   75
# 14    15     Srishti      Kashyap  77  75   93    62   49
# 15    16  Pratishtha        Singh  41  35   82    47   62
# 16    17     Kritika       Kumari  50  95   91    94   85
# 17    18      Shilpa        Singh  42  74   53    92   84
# 18    19       Komal       Sharma  55  73   81    93   79
# 19    20      Deepti        Singh  53  86   90    93   81

# %%
marks.set_index('First name', inplace= True)
marks
# Out:
#              S.no   Last name  DM  SE  GFX  DBMS  ECO
# First name
# Sandhya         1       Singh  60  87   34    55   79
# Pinki           2       Yadav  49  73   53    51   96
# Ankita          3       Verma  77  77   96    93   79
# Dipanjali       4       Singh  67  36   37    89   39
# Khushi          5     Awasthi  34  90   59    33   47
# Shalini         6         Pal  33  64   97    59   67
# Saloni          7        Gond  60  64  100    97   37
# Anushka         8  Srivastava  62  44   94    89   52
# Aditi           9      Pandey  30  91   63   100   84
# Umama          10       Anjum  84  38   37    92   86
# Muskan         11       Singh  44  58   74    81   57
# Kajal          12      Pandey  83  54   40    75   30
# Anshika        13       Yadav  35  55   57    73   79
# Deepika        14        Soni  69  87   99    82   75
# Srishti        15     Kashyap  77  75   93    62   49
# Pratishtha     16       Singh  41  35   82    47   62
# Kritika        17      Kumari  50  95   91    94   85
# Shilpa         18       Singh  42  74   53    92   84
# Komal          19      Sharma  55  73   81    93   79
# Deepti         20       Singh  53  86   90    93   81

# %%
marks['ECO'].plot(kind='pie',figsize=(10,5),title='ECO Marks')
# Out:
# <Axes: title={'center': 'ECO Marks'}, ylabel='ECO'>

# %%
marks['DBMS'].plot(kind='pie',figsize=(10,5),title='DBMS Marks')
# Out:
# <Axes: title={'center': 'DBMS Marks'}, ylabel='DBMS'>

# %%
marks['DBMS'].plot(kind='pie',figsize=(10,5),title='DBMS Marks')
marks['SE'].plot(kind='pie',figsize=(10,5),title='SE Marks')
# Out:
# <Axes: title={'center': 'SE Marks'}, ylabel='SE'>

# %%
marks[['DBMS','GFX']].plot(kind='bar',figsize=(10,5),title='DBMS Marks')
# Out:
# <Axes: title={'center': 'DBMS Marks'}, xlabel='First name'>

# %%
marks.index
# Out:
# Index(['Sandhya ', 'Pinki ', 'Ankita ', 'Dipanjali ', 'Khushi ', 'Shalini ',
#        'Saloni ', 'Anushka ', 'Aditi ', 'Umama ', 'Muskan ', 'Kajal ',
#        'Anshika ', 'Deepika ', 'Srishti ', 'Pratishtha ', 'Kritika ',
#        'Shilpa ', 'Komal ', 'Deepti '],
#       dtype='object', name='First name')

# %%
marks['ECO']
# Out:
# First name
# Sandhya        79
# Pinki          96
# Ankita         79
# Dipanjali      39
# Khushi         47
# Shalini        67
# Saloni         37
# Anushka        52
# Aditi          84
# Umama          86
# Muskan         57
# Kajal          30
# Anshika        79
# Deepika        75
# Srishti        49
# Pratishtha     62
# Kritika        85
# Shilpa         84
# Komal          79
# Deepti         81
# Name: ECO, dtype: int64

# %%
marks['DBMS']
# Out:
# First name
# Sandhya         55
# Pinki           51
# Ankita          93
# Dipanjali       89
# Khushi          33
# Shalini         59
# Saloni          97
# Anushka         89
# Aditi          100
# Umama           92
# Muskan          81
# Kajal           75
# Anshika         73
# Deepika         82
# Srishti         62
# Pratishtha      47
# Kritika         94
# Shilpa          92
# Komal           93
# Deepti          93
# Name: DBMS, dtype: int64

# %%
marks['DM']
# Out:
# First name
# Sandhya        60
# Pinki          49
# Ankita         77
# Dipanjali      67
# Khushi         34
# Shalini        33
# Saloni         60
# Anushka        62
# Aditi          30
# Umama          84
# Muskan         44
# Kajal          83
# Anshika        35
# Deepika        69
# Srishti        77
# Pratishtha     41
# Kritika        50
# Shilpa         42
# Komal          55
# Deepti         53
# Name: DM, dtype: int64

# %%
marks['GFX']
# Out:
# First name
# Sandhya         34
# Pinki           53
# Ankita          96
# Dipanjali       37
# Khushi          59
# Shalini         97
# Saloni         100
# Anushka         94
# Aditi           63
# Umama           37
# Muskan          74
# Kajal           40
# Anshika         57
# Deepika         99
# Srishti         93
# Pratishtha      82
# Kritika         91
# Shilpa          53
# Komal           81
# Deepti          90
# Name: GFX, dtype: int64

# %%
marks.columns
# Out:
# Index(['S.no', 'Last name', 'DM', 'SE', 'GFX', 'DBMS', 'ECO'], dtype='object')

# %%
marks['ECO'] /2
# Out:
# First name
# Sandhya        39.5
# Pinki          48.0
# Ankita         39.5
# Dipanjali      19.5
# Khushi         23.5
# Shalini        33.5
# Saloni         18.5
# Anushka        26.0
# Aditi          42.0
# Umama          43.0
# Muskan         28.5
# Kajal          15.0
# Anshika        39.5
# Deepika        37.5
# Srishti        24.5
# Pratishtha     31.0
# Kritika        42.5
# Shilpa         42.0
# Komal          39.5
# Deepti         40.5
# Name: ECO, dtype: float64

# %%
marks['DBMS']/2
# Out:
# First name
# Sandhya        27.5
# Pinki          25.5
# Ankita         46.5
# Dipanjali      44.5
# Khushi         16.5
# Shalini        29.5
# Saloni         48.5
# Anushka        44.5
# Aditi          50.0
# Umama          46.0
# Muskan         40.5
# Kajal          37.5
# Anshika        36.5
# Deepika        41.0
# Srishti        31.0
# Pratishtha     23.5
# Kritika        47.0
# Shilpa         46.0
# Komal          46.5
# Deepti         46.5
# Name: DBMS, dtype: float64

# %%
marks['DM']/2
# Out:
# First name
# Sandhya        30.0
# Pinki          24.5
# Ankita         38.5
# Dipanjali      33.5
# Khushi         17.0
# Shalini        16.5
# Saloni         30.0
# Anushka        31.0
# Aditi          15.0
# Umama          42.0
# Muskan         22.0
# Kajal          41.5
# Anshika        17.5
# Deepika        34.5
# Srishti        38.5
# Pratishtha     20.5
# Kritika        25.0
# Shilpa         21.0
# Komal          27.5
# Deepti         26.5
# Name: DM, dtype: float64

# %%
marks['ECO'] +2
# Out:
# First name
# Sandhya        81
# Pinki          98
# Ankita         81
# Dipanjali      41
# Khushi         49
# Shalini        69
# Saloni         39
# Anushka        54
# Aditi          86
# Umama          88
# Muskan         59
# Kajal          32
# Anshika        81
# Deepika        77
# Srishti        51
# Pratishtha     64
# Kritika        87
# Shilpa         86
# Komal          81
# Deepti         83
# Name: ECO, dtype: int64

# %%
marks
# Out:
#              S.no   Last name  DM  SE  GFX  DBMS  ECO
# First name
# Sandhya         1       Singh  60  87   34    55   79
# Pinki           2       Yadav  49  73   53    51   96
# Ankita          3       Verma  77  77   96    93   79
# Dipanjali       4       Singh  67  36   37    89   39
# Khushi          5     Awasthi  34  90   59    33   47
# Shalini         6         Pal  33  64   97    59   67
# Saloni          7        Gond  60  64  100    97   37
# Anushka         8  Srivastava  62  44   94    89   52
# Aditi           9      Pandey  30  91   63   100   84
# Umama          10       Anjum  84  38   37    92   86
# Muskan         11       Singh  44  58   74    81   57
# Kajal          12      Pandey  83  54   40    75   30
# Anshika        13       Yadav  35  55   57    73   79
# Deepika        14        Soni  69  87   99    82   75
# Srishti        15     Kashyap  77  75   93    62   49
# Pratishtha     16       Singh  41  35   82    47   62
# Kritika        17      Kumari  50  95   91    94   85
# Shilpa         18       Singh  42  74   53    92   84
# Komal          19      Sharma  55  73   81    93   79
# Deepti         20       Singh  53  86   90    93   81

# %%
marks['ECO']+=2

# %%
marks
# Out:
#              S.no   Last name  DM  SE  GFX  DBMS  ECO
# First name
# Sandhya         1       Singh  60  87   34    55   81
# Pinki           2       Yadav  49  73   53    51   98
# Ankita          3       Verma  77  77   96    93   81
# Dipanjali       4       Singh  67  36   37    89   41
# Khushi          5     Awasthi  34  90   59    33   49
# Shalini         6         Pal  33  64   97    59   69
# Saloni          7        Gond  60  64  100    97   39
# Anushka         8  Srivastava  62  44   94    89   54
# Aditi           9      Pandey  30  91   63   100   86
# Umama          10       Anjum  84  38   37    92   88
# Muskan         11       Singh  44  58   74    81   59
# Kajal          12      Pandey  83  54   40    75   32
# Anshika        13       Yadav  35  55   57    73   81
# Deepika        14        Soni  69  87   99    82   77
# Srishti        15     Kashyap  77  75   93    62   51
# Pratishtha     16       Singh  41  35   82    47   64
# Kritika        17      Kumari  50  95   91    94   87
# Shilpa         18       Singh  42  74   53    92   86
# Komal          19      Sharma  55  73   81    93   81
# Deepti         20       Singh  53  86   90    93   83

# %%
marks[['DBMS','DM']]
# Out:
#              DBMS  DM
# First name
# Sandhya        55  60
# Pinki          51  49
# Ankita         93  77
# Dipanjali      89  67
# Khushi         33  34
# Shalini        59  33
# Saloni         97  60
# Anushka        89  62
# Aditi         100  30
# Umama          92  84
# Muskan         81  44
# Kajal          75  83
# Anshika        73  35
# Deepika        82  69
# Srishti        62  77
# Pratishtha     47  41
# Kritika        94  50
# Shilpa         92  42
# Komal          93  55
# Deepti         93  53

# %%
marks['DBMS'] + marks['DM'] + marks['ECO'] + marks['GFX'] + marks['SE']
# Out:
# First name
# Sandhya        317
# Pinki          324
# Ankita         424
# Dipanjali      270
# Khushi         265
# Shalini        322
# Saloni         360
# Anushka        343
# Aditi          370
# Umama          339
# Muskan         316
# Kajal          284
# Anshika        301
# Deepika        414
# Srishti        358
# Pratishtha     269
# Kritika        417
# Shilpa         347
# Komal          383
# Deepti         405
# dtype: int64

# %%
marks['total'] = marks['DBMS'] + marks['DM'] + marks['ECO'] + marks['GFX']

# %%
marks
# Out:
#              S.no   Last name  DM  SE  GFX  DBMS  ECO  total
# First name
# Sandhya         1       Singh  60  87   34    55   81    230
# Pinki           2       Yadav  49  73   53    51   98    251
# Ankita          3       Verma  77  77   96    93   81    347
# Dipanjali       4       Singh  67  36   37    89   41    234
# Khushi          5     Awasthi  34  90   59    33   49    175
# Shalini         6         Pal  33  64   97    59   69    258
# Saloni          7        Gond  60  64  100    97   39    296
# Anushka         8  Srivastava  62  44   94    89   54    299
# Aditi           9      Pandey  30  91   63   100   86    279
# Umama          10       Anjum  84  38   37    92   88    301
# Muskan         11       Singh  44  58   74    81   59    258
# Kajal          12      Pandey  83  54   40    75   32    230
# Anshika        13       Yadav  35  55   57    73   81    246
# Deepika        14        Soni  69  87   99    82   77    327
# Srishti        15     Kashyap  77  75   93    62   51    283
# Pratishtha     16       Singh  41  35   82    47   64    234
# Kritika        17      Kumari  50  95   91    94   87    322
# Shilpa         18       Singh  42  74   53    92   86    273
# Komal          19      Sharma  55  73   81    93   81    310
# Deepti         20       Singh  53  86   90    93   83    319

# %%
# sorting 
marks.sort_values(by='total',ascending= False,inplace = True)

# %%
marks
# Out:
#              S.no   Last name  DM  SE  GFX  DBMS  ECO  total
# First name
# Ankita          3       Verma  77  77   96    93   81    347
# Deepika        14        Soni  69  87   99    82   77    327
# Kritika        17      Kumari  50  95   91    94   87    322
# Deepti         20       Singh  53  86   90    93   83    319
# Komal          19      Sharma  55  73   81    93   81    310
# Umama          10       Anjum  84  38   37    92   88    301
# Anushka         8  Srivastava  62  44   94    89   54    299
# Saloni          7        Gond  60  64  100    97   39    296
# Srishti        15     Kashyap  77  75   93    62   51    283
# Aditi           9      Pandey  30  91   63   100   86    279
# Shilpa         18       Singh  42  74   53    92   86    273
# Muskan         11       Singh  44  58   74    81   59    258
# Shalini         6         Pal  33  64   97    59   69    258
# Pinki           2       Yadav  49  73   53    51   98    251
# Anshika        13       Yadav  35  55   57    73   81    246
# Pratishtha     16       Singh  41  35   82    47   64    234
# Dipanjali       4       Singh  67  36   37    89   41    234
# Kajal          12      Pandey  83  54   40    75   32    230
# Sandhya         1       Singh  60  87   34    55   81    230
# Khushi          5     Awasthi  34  90   59    33   49    175

# %%
marks
# Out:
#              S.no   Last name  DM  SE  GFX  DBMS  ECO  total
# First name
# Ankita          3       Verma  77  77   96    93   81    347
# Deepika        14        Soni  69  87   99    82   77    327
# Kritika        17      Kumari  50  95   91    94   87    322
# Deepti         20       Singh  53  86   90    93   83    319
# Komal          19      Sharma  55  73   81    93   81    310
# Umama          10       Anjum  84  38   37    92   88    301
# Anushka         8  Srivastava  62  44   94    89   54    299
# Saloni          7        Gond  60  64  100    97   39    296
# Srishti        15     Kashyap  77  75   93    62   51    283
# Aditi           9      Pandey  30  91   63   100   86    279
# Shilpa         18       Singh  42  74   53    92   86    273
# Muskan         11       Singh  44  58   74    81   59    258
# Shalini         6         Pal  33  64   97    59   69    258
# Pinki           2       Yadav  49  73   53    51   98    251
# Anshika        13       Yadav  35  55   57    73   81    246
# Pratishtha     16       Singh  41  35   82    47   64    234
# Dipanjali       4       Singh  67  36   37    89   41    234
# Kajal          12      Pandey  83  54   40    75   32    230
# Sandhya         1       Singh  60  87   34    55   81    230
# Khushi          5     Awasthi  34  90   59    33   49    175

# %%
marks['precentage']= marks['total'] / 5

# %%
marks.sort_values(by=['total','precentage'], ascending=False, inplace=True)

# %%
fig,ax = plt.subplots(figsize=(10,5),ncols=2)
marks['total'].plot(kind='bar',ax=ax[0])
cols = ['DBMS','DM','ECO','GFX','SE']
marks[cols].plot(kind='kde',ax=ax[1])
plt.show()
